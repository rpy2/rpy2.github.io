# %%
from functools import partial
from rpy2.ipython import html
html.html_rdataframe=partial(html.html_rdataframe, table_class="docutils")

# %% [markdown]
# # tidyr in Python

# %%
from rpy2.robjects.lib.tidyr import DataFrame
# Out:
# /opt/hostedtoolcache/Python/3.10.20/x64/lib/python3.10/site-packages/rpy2/robjects/lib/dplyr.py:27: UserWarning: This was designed against dplyr versions starting with 1.1. but you have 1.2.0
#   warnings.warn(

# %% [markdown]
# (note: `dplyr` is implicitly used by `tidyr`.)
#
# In addition to that, and because this tutorial is in a notebook,
# we initialize HTML rendering for R objects (pretty display of
# R data frames).

# %%
import rpy2.ipython.html
rpy2.ipython.html.init_printing()

# %%
from collections import OrderedDict
from rpy2.robjects.vectors import (StrVector,
                                   IntVector)
dataf = DataFrame(OrderedDict(x=StrVector(("a", "b", "b")),
                              y=IntVector((3, 4, 5)),
		              z=IntVector((6, 7, 8))))
dataf
# Out:
# <rpy2.robjects.lib.tidyr.DataFrame object at 0x7ff91223f180> [RTYPES.VECSXP]
# R classes: ('data.frame',)
# [StrSexpVector, IntSexpVector, IntSexpVector]
#   x: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#   <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7ff912238200> [RTYPES.STRSXP]
#   y: <class 'rpy2.rinterface.IntSexpVector'>
#   <rpy2.rinterface.IntSexpVector object at 0x7ff9182847c0> [RTYPES.INTSXP]
#   z: <class 'rpy2.rinterface.IntSexpVector'>
#   <rpy2.rinterface.IntSexpVector object at 0x7ff912239680> [RTYPES.INTSXP]

# %%
dataf.spread('x', 'y')
# Out:
# <rpy2.robjects.lib.tidyr.DataFrame object at 0x7ff91229db40> [RTYPES.VECSXP]
# R classes: ('data.frame',)
# [IntSexpVector, IntSexpVector, IntSexpVector]
#   z: <class 'rpy2.rinterface.IntSexpVector'>
#   <rpy2.rinterface.IntSexpVector object at 0x7ff91788e4c0> [RTYPES.INTSXP]
#   a: <class 'rpy2.rinterface.IntSexpVector'>
#   <rpy2.rinterface.IntSexpVector object at 0x7ff917a23540> [RTYPES.INTSXP]
#   b: <class 'rpy2.rinterface.IntSexpVector'>
#   <rpy2.rinterface.IntSexpVector object at 0x7ff917a21f40> [RTYPES.INTSXP]

# %% [markdown]
# **Reuse. Get things done. Don't reimplement.**
